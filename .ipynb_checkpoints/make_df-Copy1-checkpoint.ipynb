# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
import pymysql

conn=pymysql.connect(host="192.9.65.20", user="jayoung", passwd="04tjvnvn23!", db="patent_DB", charset="utf8")

# %%
cursor = conn.cursor()
sql = "SELECT * FROM patent_DB.application_sample"
cursor.execute(sql)

field_names = [i[0] for i in cursor.description]
result = [value for value in cursor.fetchall()]

application_sample = pd.DataFrame(result, columns=field_names)

# %%
cursor = conn.cursor()
sql = "SELECT * FROM patent_DB.application_update"
cursor.execute(sql)

field_names = [i[0] for i in cursor.description]
result = [value for value in cursor.fetchall()]

application_update = pd.DataFrame(result, columns=field_names)

# %%
cursor = conn.cursor()
sql = "SELECT * FROM patent_DB.patent_rawassignee"
cursor.execute(sql)

field_names = [i[0] for i in cursor.description]
result = [value for value in cursor.fetchall()]

rawassignee_df = pd.DataFrame(result, columns=field_names)

# %%
cursor = conn.cursor()
sql = "SELECT * FROM patent_DB.patent_rawinventor"
cursor.execute(sql)

field_names = [i[0] for i in cursor.description]
result = [value for value in cursor.fetchall()]

rawinventor_df = pd.DataFrame(result, columns=field_names)

# %%
rawassignee_df = pd.read_csv('rawassignee.csv')
# Out:
# /home/seojayoung/miniconda3/envs/ml_python/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
rawinventor_df = pd.read_csv('rawinventor.tsv',delimiter='\t',encoding='latin1')

# %% [markdown]
# ## 삼성의 2013~2014 co-inventor 특허 데이터 추출

# %%
#applocation_sample에서 2013~2014 특허 데이터 추출
select_date_df = application_sample[application_sample['date'].str.contains('2013|2014', na=False)]

# %%
#rawassignee_df에서 2013-2014 특허 데이터 추출
select_rawassignee_df = rawassignee_df[(rawassignee_df['patent_id'].isin(select_date_df['patent_id']))==True]

#rawassignee_df의 2013-2014 특허중 삼성의 특허만 뽑음
select_rawassignee_df = select_rawassignee_df[select_rawassignee_df['organization'].str.contains('Samsung', na=False)]

# %%
#rawinventor_df에서 삼성 특허만 뽑음
samsung_p_df = rawinventor_df[(rawinventor_df['patent_id'].isin(select_rawassignee_df['patent_id']))==True]

# %%
#공동 저자 수 데이터
num_sam_co_df = samsung_p_df[['patent_id','inventor_id']].groupby('patent_id').size().reset_index(name='num_co_inventor')

#공동 저자 수가 2명 이상인 특허 데이터만 남김
num_sam_co_df = num_sam_co_df[num_sam_co_df["num_co_inventor"] > 1]

# %%
#공동 저자가 있는 삼성의 특허 데이터
sam_co_p_df = samsung_p_df[(samsung_p_df['patent_id'].isin(num_sam_co_df['patent_id']))==True]

#name_first와 name_last를 합쳐서 inventor_name 생성
sam_co_p_df['inventor_name'] = sam_co_p_df.name_first.astype(str).str.cat(sam_co_p_df.name_last.astype(str), sep=' ')
# Out:
# /home/seojayoung/miniconda3/envs/ml_python/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# 3564   RE45213   7346641-1      Weon-il Jin
# 3565   RE45213   7929705-5   Jung-hee Cheon
# 3566   RE45213   7929705-8      Eun-sun Yoo
# 3567   RE45213   6713593-4   Myung-hwan Kim
#
# [3568 rows x 3 columns]

# %%
import pickle

fin_samsung_df.to_pickle('./samsung_co_inventor_data(2013-2014).pkl')

# %% [markdown]
# ## inventor_id로 patent_id, astract 찾는 데이터 생성

# %%
#rawinventor와 application_sample은 patent_id로 연결됨
#application_sample과 application_update은 number로 연결됨

# %%
application_df = application_update.drop('number',1)
application_df['number'] = application_update['number_updated'].apply(lambda x : str(x)[:-1])

# %%
merge_df = pd.merge(rawinventor_df, application_sample, on='patent_id')
merge_df = pd.merge(merge_df, application_df, on='number')

# %%
merge_df_col = set(merge_df.columns.values)
use_col = {'inventor_id','patent_id','abstract'}

drop_col_list = list(merge_df_col - use_col)

# %%
fin_absract_df = merge_df.drop(drop_col_list,1)

# %%
fin_absract_df
# Out:
#         patent_id inventor_id  \
# 0         8203015   5306849-1
# 1         8203015   6541640-1
# 2         8203015   7750186-2
# 3         8203015   7977494-4
# 4         7883838   6599587-3
# 5         7883838   7005674-1
# 6         7883838   6599587-4
# 7         7883838   5338240-1
# 8         7883838   5441766-4
# 9         7708966   4127708-2
# 10        8230030   8230030-1
# 11        7872801   7872801-2
# 12        7872801   6717626-2
# 13        7872801   5107634-2
# 14        7872801   6561656-1
# 15        7872801   5986984-4
# 16        7979462   7979462-3
# 17        7979462   7660749-1
# 18        7979462   7979462-1
# 19        7979462   7979462-4
# 20        8270425   7808898-2
# 21        8270425   8270425-3
# 22        8270425   8270425-1
# 23        7700293   7229774-1
# 24        7837407   4273730-1
# 25        7837407   5035406-1
# 26        7837407   5035406-2
# 27        7837407   7393152-2
# 28        7837407   7393152-5
# 29        7837407   7393152-3
# ...           ...         ...
# 5560103   6716024   6435859-1
# 5560104   6750479   6300169-4
# 5560105   6631899   5099122-1
# 5560106   6387102   5368597-1
# 5560107   6439785   6439785-1
# 5560108   6586931   5698979-1
# 5560109   6821623   6821623-1
# 5560110   6768393   6545918-1
# 5560111   6742833   6059354-1
# 5560112   6614885   4959854-3
# 5560113   6654182   5029991-2
# 5560114   6691413   6090284-2
# 5560115   6612307   6612307-1
# 5560116   6511287   6478538-1
# 5560117   6457110   6457110-1
# 5560118   6594166   5195533-1
# 5560119   6473999   5926976-2
# 5560120   6566737   4282648-2
# 5560121   6825612   6825612-1
# 5560122   6810439   6567879-1
# 5560123   6816436   6816436-1
# 5560124   6638027   6543243-1
# 5560125   6647299   6647299-1
# 5560126   6397565   6397565-1
# 5560127   6786174   6776118-1
# 5560128   6542053   6504451-1
# 5560129   6690450   4688648-4
# 5560130   6688896   4632709-3
# 5560131   6596987   4112671-1
# 5560132   6698052   6698052-1
#
#                                                   abstract
# 0        The present invention relates to a process for...
# 1        The present invention relates to a process for...
# 2        The present invention relates to a process for...
# 3        The present invention relates to a process for...
# 4        An organometallic composition containing an or...
# 5        An organometallic composition containing an or...
# 6        An organometallic composition containing an or...
# 7        An organometallic composition containing an or...
# 8        An organometallic composition containing an or...
# 9        A selective catalytic reduction (SCR) system i...
# 10       A method of controlling an electronic device, ...
# 11       The Fresnel lens sheet according to the presen...
# 12       The Fresnel lens sheet according to the presen...
# 13       The Fresnel lens sheet according to the presen...
# 14       The Fresnel lens sheet according to the presen...
# 15       The Fresnel lens sheet according to the presen...
# 16       Providing a comparison of a set of similar ite...
# 17       Providing a comparison of a set of similar ite...
# 18       Providing a comparison of a set of similar ite...
# 19       Providing a comparison of a set of similar ite...
# 20       A system and method for multicast video stream...
# 21       A system and method for multicast video stream...
# 22       A system and method for multicast video stream...
# 23       The present invention relates to compositions ...
# 24       A ball joint assembly for a vehicular steering...
# 25       A ball joint assembly for a vehicular steering...
# 26       A ball joint assembly for a vehicular steering...
# 27       A ball joint assembly for a vehicular steering...
# 28       A ball joint assembly for a vehicular steering...
# 29       A ball joint assembly for a vehicular steering...
# ...                                                    ...
# 5560103  In a standard lighter, the flame is obtained b...
# 5560104  The invention concerns a semiconductor compone...
# 5560105  A method of feeding sheets includes the step o...
# 5560106  Various embodiments of a reusable surgical dev...
# 5560107  A keyboard includes a keyboard body similar to...
# 5560108  An apparatus and a method for measurement of N...
# 5560109  Recycled rubber products are made in a two ste...
# 5560110  A circuit and method for calibrating an active...
# 5560111  An arrangement in passenger vehicles, that div...
# 5560112  A system and method of directing calls is disc...
# 5560113  Lens barrel or an optical apparatus with a len...
# 5560114  An underdrain filtration system has improved p...
# 5560115  An oxygen conserver having sensing and deliver...
# 5560116  A blowing fan assembly for a window-type air c...
# 5560117  A method of reading data from a synchronous dy...
# 5560118  A step up transformer has an inert core, prima...
# 5560119  A boot, particularly a sport boot, having an e...
# 5560120  A novel passivation structure and its method o...
# 5560121  An organic light emitting diode (OLED) include...
# 5560122  An apparatus capable of determining whether co...
# 5560123  A method for processing echoes in a time-of-fl...
# 5560124  A hybrid compressor having a driveshaft driven...
# 5560125  A system and method of locating the desired te...
# 5560126  The apparatus for dispensing change of the pre...
# 5560127  A system (100, 100?) and method for robotic ma...
# 5560128  A multi-layered LC composite component achieve...
# 5560129  In order to produce an exposure apparatus, a f...
# 5560130  An electromagnetic wave shielding structure co...
# 5560131  A method and a system for monitoring combustio...
# 5560132  A device for restraining the upward movement o...
#
# [5560133 rows x 3 columns]

# %%
fin_absract_df.to_pickle('./abstract_df.pkl')

# %%
fin_absract_df[fin_absract_df['patent_id']=='8501347']['abstract']
# Out:
# 2719269    A bus bar holder for connecting electrode term...
# 2719270    A bus bar holder for connecting electrode term...
# 2719271    A bus bar holder for connecting electrode term...
# 2719272    A bus bar holder for connecting electrode term...
# Name: abstract, dtype: object
